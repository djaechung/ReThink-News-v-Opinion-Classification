# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Dictionary Extraction

# %% [markdown]
# ### Loading Full Text Data

# %%
# Loading Full Text file with cleaned author names
full_text_df = pd.read_csv("../preliminary_data/Full text w cleaned journo names.csv")

# %%
full_text_df.head()
# Out:
#          id publisher                                            subject  \
# 0  19837759  Fox News  Judge rejects Trump campaign lawsuit attemptin...
# 1  19837762  Fox News              Michigan mail-in voting: what to know
# 2  19845892       CNN  Fact check: Almost every single one of Trump's...
# 3  19845895  Politico  Trump’s Proud Boy moment sparks Black outrage ...
# 4  19846567  HuffPost  Facebook Bans Ads That Seek To ‘Delegitimize’ ...
#
#   Duplicate                                  author  \
# 0       NaN                               Paul Best
# 1       NaN                         Morgan Phillips
# 2       NaN  By Daniel Dale and Marshall Cohen, CNN
# 3       NaN                              Matt Dixon
# 4       NaN                     Sarah Ruiz-Grossman
#
#                                                 body    artdate  Month  \
# 0  U.S. District Judge Dana Christensen rejected ...  10/1/2020   10.0
# 1  As the coronavirus pandemic rages on, a number...  10/1/2020   10.0
# 2  President Donald Trumplied about a wide variet...  10/1/2020   10.0
# 3  Florida Playbook\nGary Fineout and Matt Dixon'...  10/1/2020   10.0
# 4  Facebook announced a new policy on Wednesday b...  10/1/2020   10.0
#
#      Year               cleaned_author
# 0  2020.0                    Paul Best
# 1  2020.0              Morgan Phillips
# 2  2020.0  Daniel Dale, Marshall Cohen
# 3  2020.0                   Matt Dixon
# 4  2020.0          Sarah Ruiz-Grossman

# %% [markdown]
# ### Cleaning Full Text Data

# %%
# Dropping instances where id value is not a number
full_text_df = full_text_df.drop(full_text_df[full_text_df["id"] == 'rump administration has been holding back roughly half the vaccines to en"'].index)
full_text_df = full_text_df.drop(full_text_df[full_text_df["id"] == 'Eager for more insight'].index)

# %%
# Dropping instances where the id value is NaN
full_text_df = full_text_df[full_text_df['id'].notna()]

# %%
# Converting id data types from strings to integers
# for compatability with labelled_vr data
full_text_df["id"] = full_text_df["id"].astype("int")

# %%
# Creating a dictionary of article ids matched with their respective full texts
id_fulltext_dict = pd.Series(full_text_df.body.values,index=full_text_df.id).to_dict()

# %%
# Creating a dictionary of article ids matched with their respective cleaned author names
id_cleanedauthor_dict = pd.Series(full_text_df.cleaned_author.values,index=full_text_df.id).to_dict()

# %% [markdown]
# # Dictionary Mapping to Labeled Data

# %% [markdown]
# ### Loading Labelled Data

# %%
# Loading Labelled Data
labelled_df = pd.read_csv("../preliminary_data/Labelled_VR_data_Oct2020_Jan2021.csv")

# %%
labelled_df.head()
# Out:
#    artdate  Article ID                                           Headline  \
# 0  1/31/21    29484873  Democrats are faced with a choice. Protect the...
# 1  1/31/21    29487011  GOP lawmakers seek tougher voting rules after ...
# 2  1/31/21    29487011  GOP lawmakers seek tougher voting rules after ...
# 3  1/31/21    29470814  Democratic Party Enters 2021 in Power — and Fl...
# 4  1/31/21    29470814  Democratic Party Enters 2021 in Power — and Fl...
#
#    Quote ID Article Status Article Position                 Messages  \
# 0  57524527        Opinion         Positive      Anti-Voter Policies
# 1  57524785           News          Neutral      Anti-Voter Policies
# 2  57524791           News          Neutral      Civic Participation
# 3  57544697           News          Neutral  Election Administration
# 4  57544702           News          Neutral    Election Law & Policy
#
#         Submessages Quote Position  \
# 0  Vote Suppression       Positive
# 1             Fraud       Positive
# 2  Partisan Turnout        Neutral
# 3            Budget       Positive
# 4  Electoral System        Neutral
#
#                                                QText  \
# 0  "In addition to the millions and millions of v...
# 1  Despite the fact that Republicans know and und...
# 2  That's the base that is loyal to Donald Trump....
# 3  The party rarely invests in places where there...
# 4  the president and D.N.C. enjoyed “an historica...
#
#                  Source Name                 Source Type Source Gender  \
# 0            Fred Wertheimer              Non-Profit/NGO          Male
# 1             Debra Bazemore        State/Local Official        Female
# 2             Debra Bazemore        State/Local Official        Female
# 3              Donna Brazile  Partisans/Fmr. Politicians        Female
# 4  Jennifer O'Malley Dillon   Partisans/Fmr. Politicians        Female
#
#   Constituent Group                  Media Name  \
# 0             Other         Washington Post.com
# 1               NaN  Associated Press Newswires
# 2               NaN  Associated Press Newswires
# 3             Other          The New York Times
# 4               NaN          The New York Times
#
#                             Journalist Name  \
# 0                        By E.J. Dionne Jr.
# 1  By ANTHONY IZAGUIRRE and ACACIA CORONADO
# 2  By ANTHONY IZAGUIRRE and ACACIA CORONADO
# 3                       By Shane Goldmacher
# 4                       By Shane Goldmacher
#
#                                       Article Issues    Custom Group
# 0  VR: Pro-Voter Policies, H.R. 1, VR: Anti-Voter...      Commentary
# 1                                                NaN         Georgia
# 2                                                NaN         Georgia
# 3                                                NaN  South Carolina
# 4                                                NaN  South Carolina

# %%
# Quick sanity check: there are 4240 unique values in the Article ID column,
# so we expect 4240 records in the df once we drop Article ID duplicates
labelled_df["Article ID"].value_counts()
# Out:
# 21830535    69
# 21879932    46
# 22978971    44
# 27738629    44
# 21902953    43
#             ..
# 21703471     1
# 21688367     1
# 21650612     1
# 21687860     1
# 19748196     1
# Name: Article ID, Length: 4240, dtype: int64

# %% [markdown]
# ### Dropping Article ID Duplicates from Labelled Data

# %%
# Dropping Article ID duplicates
labelled_df = labelled_df.drop_duplicates(subset='Article ID', keep="last")
labelled_df
# Out:
#        artdate  Article ID                                           Headline  \
# 8      1/31/21    29470814  Democratic Party Enters 2021 in Power — and Fl...
# 11     1/31/21    29458845  A call for another Great Migration, this time ...
# 14     1/31/21    29474652  Trump Raised $255.4 Million in 8 Weeks as He S...
# 17     1/31/21    29484873  Democrats are faced with a choice. Protect the...
# 24     1/31/21    29487011  GOP lawmakers seek tougher voting rules after ...
# ...        ...         ...                                                ...
# 18986  9/30/20    19775392  Florida might not know on election night wheth...
# 18987  9/30/20    19758647  ELECTION 2020; Fact-checking: A stream of fals...
# 18988  9/30/20    19741823  Trump Refuses to Condemn White Supremacists: ‘...
# 18989  9/30/20    19745384  Vote-by-mail is not full of fraud, despite Tru...
# 18990  9/30/20    19748196  AP FACT CHECK: False claims flood Trump-Biden ...
#
#        Quote ID Article Status Article Position                 Messages  \
# 8      57544827           News          Neutral  Election Administration
# 11     57544985           News          Neutral      Civic Participation
# 14     57522610        Opinion          Neutral      Civic Participation
# 17     57545348        Opinion         Positive      Anti-Voter Policies
# 24     57524790           News          Neutral      Anti-Voter Policies
# ...         ...            ...              ...                      ...
# 18986  56064344           News          Neutral    Election Law & Policy
# 18987  56063497           News          Neutral      Election Protection
# 18988  56064770           News          Neutral      Anti-Voter Policies
# 18989  56069385        Opinion          Neutral       Pro-Voter Policies
# 18990  56063342           News          Neutral      Anti-Voter Policies
#
#                 Submessages Quote Position  \
# 8                    Budget       Positive
# 11       Voter Registration       Positive
# 14          Overall Turnout        Neutral
# 17                 Voter ID       Positive
# 24                 Voter ID       Positive
# ...                     ...            ...
# 18986      Electoral System        Neutral
# 18987  Foreign Intervention       Negative
# 18988         Poll Watchers       Negative
# 18989   Provisional Ballots        Neutral
# 18990                 Fraud       Negative
#
#                                                    QText          Source Name  \
# 8      Democrats had the opportunity to spend money i...        Donna Brazile
# 11     Georgia's expanding African American populatio...         Charles Blow
# 14     Mr. Trump’s strongest fund-raising came in the...     Shane Goldmacher
# 17     The 106 bills the center identified in 28 stat...     Shane Goldmacher
# 24     laws such as prohibiting online voter registra...  Thomas Buser-Clancy
# ...                                                  ...                  ...
# 18986  "I think everybody would like to have an answe...           Rick Scott
# 18987  the ballots could be forged by anyone, includi...     Donald Trump OLD
# 18988  said he wanted them to go to the polls and “wa...     Donald Trump OLD
# 18989                      “A solicited ballot is okay,”     Donald Trump OLD
# 18990                          “It’s a rigged election.”     Donald Trump OLD
#
#                       Source Type Source Gender Constituent Group  \
# 8      Partisans/Fmr. Politicians        Female             Other
# 11               Media/Journalist          Male               NaN
# 14               Media/Journalist          Male               NaN
# 17               Media/Journalist          Male               NaN
# 24              Constituent Group          Male              ACLU
# ...                           ...           ...               ...
# 18986           US Senate & Staff          Male               NaN
# 18987            Federal Official          Male             Other
# 18988            Federal Official          Male             Other
# 18989            Federal Official          Male             Other
# 18990            Federal Official          Male             Other
#
#                        Media Name                           Journalist Name  \
# 8              The New York Times                       By Shane Goldmacher
# 11            The Washington Post                             Carlos Lozada
# 14             The New York Times     By Shane Goldmacher and Rachel Shorey
# 17            Washington Post.com                        By E.J. Dionne Jr.
# 24     Associated Press Newswires  By ANTHONY IZAGUIRRE and ACACIA CORONADO
# ...                           ...                                       ...
# 18986            The Miami Herald                           By David Smiley
# 18987           Los Angeles Times                            CHRIS MEGERIAN
# 18988             The Daily Beast                               Will Sommer
# 18989                         VOX                                 Jen Kirby
# 18990  Associated Press Newswires           By CALVIN WOODWARD and HOPE YEN
#
#                                           Article Issues    Custom Group
# 8                                                    NaN  South Carolina
# 11                                                   NaN         Georgia
# 14     VR: Anti-Voter Policies, VR: Civic Participati...      Commentary
# 17     VR: Pro-Voter Policies, H.R. 1, VR: Anti-Voter...      Commentary
# 24                                                   NaN         Georgia
# ...                                                  ...             ...
# 18986                                                NaN    Florida (FL)
# 18987                                                NaN             NaN
# 18988                                                NaN             NaN
# 18989                             VR: Pro-Voter Policies       Wisconsin
# 18990                                                NaN    Pennsylvania
#
# [4240 rows x 18 columns]

# %% [markdown]
# ### Mapping Dictionaries to the Labelled Data to Create New Columns

# %%
# Mapping the id-to-fulltext dictionary to create a Full Text column in the labelled df
labelled_df['Full Text']= labelled_df['Article ID'].map(id_fulltext_dict)

# %%
# Mapping the id-to-cleanedauthor dictionary to create a Cleaned Author column in the labelled df
labelled_df['Cleaned Author']= labelled_df['Article ID'].map(id_cleanedauthor_dict)

# %%
# Sanity check to see if these columns have been added
labelled_df.head(1)
# Out:
#    artdate  Article ID                                           Headline  \
# 8  1/31/21    29470814  Democratic Party Enters 2021 in Power — and Fl...
#
#    Quote ID Article Status Article Position                 Messages  \
# 8  57544827           News          Neutral  Election Administration
#
#   Submessages Quote Position  \
# 8      Budget       Positive
#
#                                                QText    Source Name  \
# 8  Democrats had the opportunity to spend money i...  Donna Brazile
#
#                   Source Type Source Gender Constituent Group  \
# 8  Partisans/Fmr. Politicians        Female             Other
#
#            Media Name      Journalist Name Article Issues    Custom Group  \
# 8  The New York Times  By Shane Goldmacher            NaN  South Carolina
#
#                                            Full Text    Cleaned Author
# 8  The Democratic National Committee has a roughl...  Shane Goldmacher

# %%
# Noting how many records are in the labelled data df so far, for reference later
num_records_pre_clean = len(labelled_df)
num_records_pre_clean
# Out:
# 4240

# %% [markdown]
# ### Cleaning Updated Labelled df

# %%
# Drop articles that don't have a corresponding full text (where full text value is NaN)
labelled_df = labelled_df[labelled_df['Full Text'].notna()]

#Drop any remaining Spanish-language articles
spanish_outlets = ['El Nuevo Herald', 'El Diario La Prensa', 'Univision', 'AP Spanish Worldstream']

labelled_df = labelled_df[-labelled_df["Media Name"].isin(spanish_outlets)]

labelled_df
# Out:
#        artdate  Article ID                                           Headline  \
# 8      1/31/21    29470814  Democratic Party Enters 2021 in Power — and Fl...
# 11     1/31/21    29458845  A call for another Great Migration, this time ...
# 14     1/31/21    29474652  Trump Raised $255.4 Million in 8 Weeks as He S...
# 17     1/31/21    29484873  Democrats are faced with a choice. Protect the...
# 24     1/31/21    29487011  GOP lawmakers seek tougher voting rules after ...
# ...        ...         ...                                                ...
# 18968  10/1/20    19978767  County, AG take vote spar to state's top court...
# 18969  10/1/20    19943666  Dawn Porter on Documenting Rep. John Lewis: 'T...
# 18971  10/1/20    19884512  Debate has little substance for voters; Lack o...
# 18972  10/1/20    19933963  Elecciones 2020: Lo que necesitas saber para v...
# 18973  10/1/20    19951546                            Election 2020, ADVISORY
#
#        Quote ID Article Status Article Position                 Messages  \
# 8      57544827           News          Neutral  Election Administration
# 11     57544985           News          Neutral      Civic Participation
# 14     57522610        Opinion          Neutral      Civic Participation
# 17     57545348        Opinion         Positive      Anti-Voter Policies
# 24     57524790           News          Neutral      Anti-Voter Policies
# ...         ...            ...              ...                      ...
# 18968  57720233           News          Neutral       Pro-Voter Policies
# 18969  57720248           News          Neutral                      NaN
# 18971  57720268           News          Neutral      Civic Participation
# 18972  57720288           News          Neutral                      NaN
# 18973  57720298           News          Neutral                      NaN
#
#               Submessages Quote Position  \
# 8                  Budget       Positive
# 11     Voter Registration       Positive
# 14        Overall Turnout        Neutral
# 17               Voter ID       Positive
# 24               Voter ID       Positive
# ...                   ...            ...
# 18968        Vote by Mail        Neutral
# 18969                 NaN        Neutral
# 18971    Partisan Turnout        Neutral
# 18972                 NaN        Neutral
# 18973                 NaN        Neutral
#
#                                                    QText          Source Name  \
# 8      Democrats had the opportunity to spend money i...        Donna Brazile
# 11     Georgia's expanding African American populatio...         Charles Blow
# 14     Mr. Trump’s strongest fund-raising came in the...     Shane Goldmacher
# 17     The 106 bills the center identified in 28 stat...     Shane Goldmacher
# 24     laws such as prohibiting online voter registra...  Thomas Buser-Clancy
# ...                                                  ...                  ...
# 18968  The deadline for voters to apply for a mail ba...           Susan Hays
# 18969  Clearly, as we are nearing closer and closer t...                  NaN
# 18971  I think they were looking for a reason to vote...     Catherine Alonzo
# 18972  Los residentes del Condado Pima están haciendo...                  NaN
# 18973  President Trump’s reelection campaign and Repu...                  NaN
#
#                       Source Type Source Gender Constituent Group  \
# 8      Partisans/Fmr. Politicians        Female             Other
# 11               Media/Journalist          Male               NaN
# 14               Media/Journalist          Male               NaN
# 17               Media/Journalist          Male               NaN
# 24              Constituent Group          Male              ACLU
# ...                           ...           ...               ...
# 18968            Private Attorney        Female               NaN
# 18969                         NaN           NaN               NaN
# 18971  Partisans/Fmr. Politicians        Female               NaN
# 18972                         NaN           NaN               NaN
# 18973                         NaN           NaN               NaN
#
#                        Media Name  \
# 8              The New York Times
# 11            The Washington Post
# 14             The New York Times
# 17            Washington Post.com
# 24     Associated Press Newswires
# ...                           ...
# 18968           Houston Chronicle
# 18969                    The Root
# 18971        The Arizona Republic
# 18972      The Arizona Daily Star
# 18973  Associated Press Newswires
#
#                                          Journalist Name  \
# 8                                    By Shane Goldmacher
# 11                                         Carlos Lozada
# 14                 By Shane Goldmacher and Rachel Shorey
# 17                                    By E.J. Dionne Jr.
# 24              By ANTHONY IZAGUIRRE and ACACIA CORONADO
# ...                                                  ...
# 18968                         Zach Despart; Staff writer
# 18969                                        No by-line,
# 18971  By Yvonne Wingett Sanchez and Ronald J. Hansen...
# 18972                                   Veronica M. Cruz
# 18973                                        No by-line,
#
#                                           Article Issues    Custom Group  \
# 8                                                    NaN  South Carolina
# 11                                                   NaN         Georgia
# 14     VR: Anti-Voter Policies, VR: Civic Participati...      Commentary
# 17     VR: Pro-Voter Policies, H.R. 1, VR: Anti-Voter...      Commentary
# 24                                                   NaN         Georgia
# ...                                                  ...             ...
# 18968                                                NaN           Texas
# 18969                            VR: Anti-Voter Policies         Georgia
# 18971                                                NaN         Arizona
# 18972                            VR: Civic Participation         Arizona
# 18973                        VR: Election Administration             NaN
#
#                                                Full Text  \
# 8      The Democratic National Committee has a roughl...
# 11     A Black Power Manifesto By Charles M. Blow. Ha...
# 14     The former president’s fund-raising slowed sig...
# 17     The Democrats can use their House and Senate m...
# 24     AUSTIN, Texas (AP) — Republican lawmakers in s...
# ...                                                  ...
# 18968  Harris County Clerk Christopher Hollins' plan ...
# 18969  It’s been a few months since the world lost on...
# 18971  If Arizona voters tuned in to the first presid...
# 18972  La elección general es el 3 de noviembre\n\nPo...
# 18973  Here are today’s plans for coverage of Electio...
#
#                                  Cleaned Author
# 8                              Shane Goldmacher
# 11                                Carlos Lozada
# 14              Shane Goldmacher, Rachel Shorey
# 17                              E.J. Dionne Jr.
# 24           Anthony Izaguirre, Acacia Coronado
# ...                                         ...
# 18968                                       NaN
# 18969                                       NaN
# 18971  Yvonne Wingett Sanchez, Ronald J. Hansen
# 18972                          Veronica M. Cruz
# 18973                                       NaN
#
# [3547 rows x 20 columns]

# %%
# Noting how many records are in the labelled data df now that records without full text have been dropped
num_records_post_clean = len(labelled_df)
num_records_post_clean
# Out:
# 3547

# %%
# Determining how many articles did not have an associated full text based on how many records
# there were before and after the data cleaning.
num_records_wout_fulltext = num_records_pre_clean - num_records_post_clean
print("Number of Articles Dropped Due to Lack of Full text (or Spanish): " + str(num_records_wout_fulltext))
# Out:
# Number of Articles Dropped Due to Lack of Full text (or Spanish): 693

# %%
#Drop unnecessary quote-level columns
labelled_df = labelled_df.drop(['Quote ID', 
                                'Quote Position',
                                'QText',
                                'Messages',
                                'Submessages',
                                'Source Name', 
                                'Source Type', 
                                'Source Gender',
                                'Constituent Group'], axis=1)

# %% [markdown]
# ### Add hand-annotated edits: opinion article type, and edits to News/Opinion labels (i.e. quality control edits where the orginal label was incorrect)

# %%
op_type_df = pd.read_excel("../preliminary_data/Labelled_VR_data_opinion_type_annotation.xlsx")
label_qc_df = pd.read_excel("../preliminary_data/Labelled_VR_data_labelQC_annotation.xlsx")

#Create dict of label_qc edits column
id_qcedits_dict = pd.Series(label_qc_df.edits.values,index=label_qc_df["Article ID"]).to_dict()

#Create dict of opinion type edits column and article type column
id_op_type_edits_dict = pd.Series(op_type_df.Edits.values,index=op_type_df["Article ID"]).to_dict()
id_op_type_dict = pd.Series(op_type_df["opinion_type"].values,index=op_type_df["Article ID"]).to_dict()


#Map label_qc edits column to main df
labelled_df['QCedits']= labelled_df['Article ID'].map(id_qcedits_dict)

#Map edits column from opinion type file to main df
labelled_df['op_type_edits']= labelled_df['Article ID'].map(id_op_type_edits_dict)


#Drop articles identified as irrelevant in hand annotation
labelled_df = labelled_df[-(labelled_df.op_type_edits == "Irrelevant") & -(labelled_df.QCedits == "Irrelevant")]


#Create article type column
labelled_df['opinion_type']= labelled_df['Article ID'].map(id_op_type_dict)

#Fill news_opinion column first with edits from annotated data, then with the original labels
labelled_df["news_opinion"] = labelled_df["QCedits"].fillna(labelled_df["op_type_edits"]).fillna(labelled_df["Article Status"])

#Replace old labels column with new, edited labels column
labelled_df["Article Status"] = labelled_df["news_opinion"]

labelled_df = labelled_df.drop(['op_type_edits', 'QCedits', 'news_opinion'], axis=1)

# %%
# Exporting the modified Labelled Data to excel
# Changed from csv to excel b/c csv file was exporting with an empty row at row 248 
labelled_df.to_excel("../cleaned_data/Labelled_VR_data_Oct2020_Jan2021_wfulltext.xlsx", index=False)

# %% [markdown]
# # Creating a File of all Unlabelled Articles

# %%
#Create list of Article IDs for labelled articles
labelled_articleid_list = labelled_df["Article ID"].to_list()

#Filter the full text file to only keep articles for which labelled data does not exist
full_text_df = full_text_df[-full_text_df['id'].isin(labelled_articleid_list)]

# %%
# Only keep necessary columns
unlabelled_df = full_text_df[['id', 
                             'publisher', 
                             'subject', 
                             'author', 
                             'body', 
                             'artdate',
                             'cleaned_author']]

# %%
# Exporting to csv
unlabelled_df.to_csv("../cleaned_data/Unlabelled_Articles_VR_data_Oct2020_Jan2021.csv")
